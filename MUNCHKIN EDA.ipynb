# %% [markdown]
# # Importing modules and Data

# %%
import pandas as pd
import numpy as np

# Plotting
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

from IPython.display import Image


df = pd.read_csv('/Users/dhruvpatel/Desktop/MUNCHKIN/DS Test Dataset.csv',parse_dates=['WEEK_START'], index_col='WEEK_START')

# %% [markdown]
# # Exploring Data

# %%
df.describe()
# one NAN present in the dataset
# Out:
#              orders           POS       ON_HAND       Price         WOS  \
# count    456.000000    455.000000    454.000000  455.000000  454.000000
# mean    4193.473684   4066.628571  15538.337004    7.709400    3.595606
# std     3247.046556   2996.355204  14704.313422    3.917288    1.534380
# min      148.800000    273.000000    229.000000    3.597535    0.330000
# 25%     1221.600000    814.500000   3216.500000    3.944888    2.649177
# 50%     3866.400000   3723.000000  11786.000000    6.263365    3.283386
# 75%     5874.000000   5830.500000  21146.500000   12.925000    4.483787
# max    13266.000000  11591.000000  76932.000000   14.940000   10.880000
#
#        STORE_COUNT
# count   304.000000
# mean   1790.651316
# std      14.918817
# min    1720.000000
# 25%    1782.000000
# 50%    1792.000000
# 75%    1800.000000
# max    1816.000000

# %% [markdown]
# # How much Revenue generated in last 3 years for 3 items?

# %%
Image("/Users/dhruvpatel/Desktop/REV over time.png")

# %% [markdown]
# # Percentage Revenue Genrated

# %%
Image("/Users/dhruvpatel/Desktop/% of Revenue.png")

# %% [markdown]
# ### Revenue is generated by multiplying price with POS.
# #### 2016 and 2017 spoutless and 2018 and 2019 Acessories items have generated comparitively high revenue
#
#
#
#
# # How does order changes overtime for each item?

# %%
Image("/Users/dhruvpatel/Desktop/orders overtime.png")

# %% [markdown]
# # How does Price of an item changes over time?

# %%
Image("/Users/dhruvpatel/Desktop/Price of Product overtime.png")

# %% [markdown]
# #### Price of Cups and Pacifier remains constant over time. Travel price fluctuated in between, but overall its constant too.
#
#
#
# # How does POS changes over time?

# %%
Image(data="/Users/dhruvpatel/Desktop/POS over time.png")

# %% [markdown]
# # Making Corelation Plot

# %%
corr = df[["orders","POS","Price"]].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_45c74af0_b73d_11e9_8630_acde48001122row0_col0 {
#             background-color:  #b40426;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row0_col1 {
#             background-color:  #c32e31;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row0_col2 {
#             background-color:  #4358cb;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row1_col0 {
#             background-color:  #c32e31;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row1_col1 {
#             background-color:  #b40426;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_45c74af0_b73d_11e9_8630_acde48001122row2_col2 {
#             background-color:  #b40426;
# ...

# %% [markdown]
# ## It can be infered from the plot that Point of Sale is highly correlated with Orders and negatively correlated with price.
#
# ## This makes sense that when the price increases the retailers will not give much orders to Munchkin. Assuming POS remains constant
#
# ## If Sale increases (causes demand of SKUs), retailers will give order regardless of price.

# %% [markdown]
# # Time Series Analysis is done in different file for each item
